# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('img1.jpeg')

# %%
image
# Out:
# array([[[255, 229, 202],
#         [255, 229, 202],
#         [255, 229, 202],
#         ...,
#         [254, 232, 204],
#         [254, 232, 204],
#         [254, 232, 204]],
#
#        [[255, 229, 202],
#         [255, 229, 202],
#         [255, 229, 202],
#         ...,
#         [254, 232, 204],
#         [254, 232, 204],
#         [254, 232, 204]],
#
#        [[255, 229, 202],
#         [255, 229, 202],
#         [255, 229, 202],
#         ...,
#         [254, 232, 204],
#         [254, 232, 204],
#         [254, 232, 204]],
#
#        ...,
#
#        [[255, 247, 229],
#         [255, 247, 229],
#         [255, 247, 229],
#         ...,
#         [254, 251, 237],
#         [254, 251, 237],
#         [254, 251, 237]],
#
#        [[254, 248, 229],
#         [254, 248, 229],
#         [254, 248, 229],
#         ...,
#         [255, 252, 238],
#         [255, 252, 238],
#         [255, 252, 238]],
#
#        [[254, 248, 229],
#         [254, 248, 229],
#         [254, 248, 229],
#         ...,
#         [255, 252, 238],
#         [255, 252, 238],
#         [255, 252, 238]]], dtype=uint8)

# %%
plt.imshow(image)

# %%
if image is None:
    print("Error loading image.")
    exit()

# %%
b_channel, g_channel, r_channel = cv2.split(image)

# %%
hist_b = cv2.calcHist([b_channel], [0], None, [256], [0, 256])
hist_g = cv2.calcHist([g_channel], [0], None, [256], [0, 256])
hist_r = cv2.calcHist([r_channel], [0], None, [256], [0, 256])

# %%
plt.figure(figsize=(10, 5))
plt.title('Color Channel Histograms')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.plot(hist_b, color='blue', label='Blue Channel')

plt.plot(hist_g, color='green', label='Green Channel')

plt.plot(hist_r, color='red', label='Red Channel')
plt.legend()

plt.show()

# %%
image1 = cv2.imread('img.jpeg')

# %%
image1
# Out:
# array([[[91, 63, 29],
#         [91, 63, 29],
#         [93, 62, 29],
#         ...,
#         [86, 54, 19],
#         [89, 57, 21],
#         [79, 50, 13]],
#
#        [[91, 63, 29],
#         [91, 63, 29],
#         [92, 61, 28],
#         ...,
#         [84, 52, 17],
#         [86, 54, 18],
#         [80, 51, 14]],
#
#        [[92, 61, 28],
#         [92, 61, 28],
#         [92, 62, 27],
#         ...,
#         [79, 47, 12],
#         [80, 48, 12],
#         [79, 50, 13]],
#
#        ...,
#
#        [[10, 18, 17],
#         [22, 30, 29],
#         [19, 27, 26],
#         ...,
#         [ 2, 12, 12],
#         [ 0,  1,  1],
#         [ 9, 22, 24]],
#
#        [[22, 30, 29],
#         [ 8, 16, 15],
#         [19, 27, 26],
#         ...,
#         [ 3, 13, 13],
#         [12, 24, 24],
#         [32, 45, 47]],
#
#        [[10, 18, 17],
#         [ 0,  5,  4],
#         [ 7, 15, 14],
#         ...,
#         [ 7, 17, 17],
#         [11, 23, 23],
#         [27, 41, 40]]], dtype=uint8)

# %%
plt.imshow(image1)

# %%
b_channel, g_channel, r_channel = cv2.split(image1)

# %%
hist_b = cv2.calcHist([b_channel], [0], None, [256], [0, 256])
hist_g = cv2.calcHist([g_channel], [0], None, [256], [0, 256])
hist_r = cv2.calcHist([r_channel], [0], None, [256], [0, 256])

# %%
plt.figure(figsize=(10, 5))
plt.title('Color Channel Histograms')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
# Blue channel histogram
plt.plot(hist_b, color='blue', label='Blue Channel')
# Green channel histogram
plt.plot(hist_g, color='green', label='Green Channel')
# Red channel histogram
plt.plot(hist_r, color='red', label='Red Channel')
plt.legend()
plt.show()
